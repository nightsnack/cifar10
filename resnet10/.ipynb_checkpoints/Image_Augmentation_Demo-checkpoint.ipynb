# %%
# %matplotlib inline
import d2lzh as d2l
import mxnet as mx
from mxnet import autograd, gluon, image, init, nd
from mxnet.gluon import data as gdata, loss as gloss, utils as gutils
import sys
import time

# %%
d2l.set_figsize()
img = image.imread('./data/train_tiny/47.png')
d2l.plt.imshow(img.asnumpy())

# %%
def show_images(imgs, num_rows, num_cols, scale=2):
    figsize = (num_cols * scale, num_rows * scale)
    _, axes = d2l.plt.subplots(num_rows, num_cols, figsize=figsize)
    for i in range(num_rows):
        for j in range(num_cols):
            axes[i][j].imshow(imgs[i * num_cols + j].asnumpy())
            axes[i][j].axes.get_xaxis().set_visible(False)
            axes[i][j].axes.get_yaxis().set_visible(False)
    return axes

# %%
# Flipping
num_rows = 2
num_cols = 2
Y = [gdata.vision.transforms.RandomFlipLeftRight()(img) for _ in range(num_rows * num_cols)]
show_images(Y, num_rows, num_cols)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1a27718a58>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a27d4a828>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1114b1c50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a27cff518>]],
#       dtype=object)

# %%
# Fading
num_rows = 2
num_cols = 2
Y = [gdata.vision.transforms.RandomBrightness(0.5)(img) for _ in range(num_rows * num_cols)]
show_images(Y, num_rows, num_cols)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1a27b6e898>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x111503860>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a2795f710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a27f9b4a8>]],
#       dtype=object)

# %%
multi_operation = gdata.vision.transforms.Compose([
    # Resize(Magnify)
    gdata.vision.transforms.Resize(40),

    # Normalization
    gdata.vision.transforms.Normalize([0.5, 0.5, 0.5],
                                      [0.2, 0.2, 0.2])])
print(multi_operation)
# Out:
# Compose(
#   (0): Resize(
#
#   )
#   (1): RandomResizedCrop(
#
#   )
#   (2): Normalize(
#
#   )
# )

# %%
# Apply
num_rows = 2
num_cols = 2
Y = [multi_operation()(img) for _ in range(num_rows * num_cols)]
show_images(Y, num_rows, num_cols)
# Out:
# ---------------------------------------------------------------------------
# MXNetError                                Traceback (most recent call last)
# <ipython-input-58-221102bdddcb> in <module>
#       4
#       5 # Apply
# ----> 6 apply(img, multi_operation)
#
# <ipython-input-58-221102bdddcb> in apply(img, aug, num_rows, num_cols, scale)
#       1 def apply(img, aug, num_rows=2, num_cols=4, scale=1.5):
# ----> 2     Y = [aug(img) for _ in range(num_rows * num_cols)]
#       3     show_images(Y, num_rows, num_cols, scale)
#       4
#       5 # Apply
#
# <ipython-input-58-221102bdddcb> in <listcomp>(.0)
#       1 def apply(img, aug, num_rows=2, num_cols=4, scale=1.5):
# ----> 2     Y = [aug(img) for _ in range(num_rows * num_cols)]
#       3     show_images(Y, num_rows, num_cols, scale)
#       4
#       5 # Apply
#
# /anaconda3/lib/python3.7/site-packages/mxnet/gluon/block.py in __call__(self, *args)
#     546             hook(self, args)
#     547
# --> 548         out = self.forward(*args)
#     549
#     550         for hook in self._forward_hooks.values():
#
# /anaconda3/lib/python3.7/site-packages/mxnet/gluon/nn/basic_layers.py in forward(self, x)
#      51     def forward(self, x):
#      52         for block in self._children.values():
# ---> 53             x = block(x)
#      54         return x
#      55
#
# /anaconda3/lib/python3.7/site-packages/mxnet/gluon/block.py in __call__(self, *args)
#     546             hook(self, args)
#     547
# --> 548         out = self.forward(*args)
#     549
#     550         for hook in self._forward_hooks.values():
#
# /anaconda3/lib/python3.7/site-packages/mxnet/gluon/block.py in forward(self, x, *args)
#     923                     params = {i: j.data(ctx) for i, j in self._reg_params.items()}
#     924
# --> 925                 return self.hybrid_forward(ndarray, x, *args, **params)
#     926
#     927         assert isinstance(x, Symbol), \
#
# /anaconda3/lib/python3.7/site-packages/mxnet/gluon/data/vision/transforms.py in hybrid_forward(self, F, x)
#     188
#     189     def hybrid_forward(self, F, x):
# --> 190         return F.image.normalize(x, self._mean, self._std)
#     191
#     192
#
# /anaconda3/lib/python3.7/site-packages/mxnet/ndarray/register.py in normalize(data, mean, std, out, name, **kwargs)
#
# /anaconda3/lib/python3.7/site-packages/mxnet/_ctypes/ndarray.py in _imperative_invoke(handle, ndargs, keys, vals, out)
#      90         c_str_array(keys),
#      91         c_str_array([str(s) for s in vals]),
# ---> 92         ctypes.byref(out_stypes)))
#      93
#      94     if original_output is not None:
#
# /anaconda3/lib/python3.7/site-packages/mxnet/base.py in check_call(ret)
#     251     """
#     252     if ret != 0:
# --> 253         raise MXNetError(py_str(_LIB.MXGetLastError()))
#     254
#     255
#
# MXNetError: [22:57:45] src/operator/image/./image_random-inl.h:251: Check failed: nchannels == 3 || nchannels == 1: The first dimension of input tensor must be the channel dimension with either 1 or 3 elements, but got input with shape [32,32,3]
# Stack trace:
#   [bt] (0) 1   libmxnet.so                         0x000000011f8d2929 mxnet::op::NDArrayOpProp::~NDArrayOpProp() + 4473
#   [bt] (1) 2   libmxnet.so                         0x000000011f8d1d19 mxnet::op::NDArrayOpProp::~NDArrayOpProp() + 1385
#   [bt] (2) 3   libmxnet.so                         0x000000011fb90d76 dmlc::parameter::FieldEntry<void*>& dmlc::Parameter<mxnet::op::NDArrayOpParam>::DECLARE<void*>(dmlc::parameter::ParamManagerSingleton<mxnet::op::NDArrayOpParam>*, std::__1::basic_string<char, std::__1::char_traits<char>, std::__1::allocator<char> > const&, void*&) + 105430
#   [bt] (3) 4   libmxnet.so                         0x0000000120e4ff23 mxnet::imperative::SetShapeType(mxnet::Context const&, nnvm::NodeAttrs const&, std::__1::vector<mxnet::NDArray*, std::__1::allocator<mxnet::NDArray*> > const&, std::__1::vector<mxnet::NDArray*, std::__1::allocator<mxnet::NDArray*> > const&, mxnet::DispatchMode*) + 1603
#   [bt] (4) 5   libmxnet.so                         0x0000000120e4e83c mxnet::Imperative::Invoke(mxnet::Context const&, nnvm::NodeAttrs const&, std::__1::vector<mxnet::NDArray*, std::__1::allocator<mxnet::NDArray*> > const&, std::__1::vector<mxnet::NDArray*, std::__1::allocator<mxnet::NDArray*> > const&) + 716
#   [bt] (5) 6   libmxnet.so                         0x0000000120d9448e SetNDInputsOutputs(nnvm::Op const*, std::__1::vector<mxnet::NDArray*, std::__1::allocator<mxnet::NDArray*> >*, std::__1::vector<mxnet::NDArray*, std::__1::allocator<mxnet::NDArray*> >*, int, void* const*, int*, int, int, void***) + 1582
#   [bt] (6) 7   libmxnet.so                         0x0000000120d951d0 MXImperativeInvokeEx + 176
#   [bt] (7) 8   libffi.6.dylib                      0x000000010ffc3884 ffi_call_unix64 + 76
